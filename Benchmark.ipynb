# %%
# !python3 -c "import pykeops; pykeops.clean_pykeops();"
# Out:
# [KeOps] /home/nizarben/.cache/keops2.2.3/Linux_ankhhaf_5.15.0-131-generic_p3.12.2 has been cleaned.
# [KeOps] Compiling cuda jit compiler engine ... OK
# [pyKeOps] Compiling nvrtc binder for python ... OK

# %%
print('Making this robust on Multi-head attention')
# Out:
# Making this robust on Multi-head attention

# %%
import matplotlib.pyplot as plt
from MHA import seq_lengths, times_standard, times_keops
plt.figure(figsize=(8,5))
plt.plot(seq_lengths, times_standard, marker='o', label='Standard Attention')
plt.plot(seq_lengths, times_keops, marker='s', label='KeOps Attention')
plt.xlabel("Sequence Length")
plt.ylabel("Forward Pass Time (ms)")
plt.title("Runtime vs Sequence Length")
plt.legend()
plt.show()
# Out:
# Sequence length = 128
# SoftMax
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 from MHA import seq_lengths, times_standard, times_keops
#       3 plt.figure(figsize=(8,5))
#       4 plt.plot(seq_lengths, times_standard, marker='o', label='Standard Attention')
#
# File ~/attention/MHA.py:183
#     181 with torch.no_grad():
#     182     out_std = attn_std(x, mask=rand_mask)
# --> 183     out_keops = attn_keops(x, mask=rand_mask)
#     185 # Check correctness:
#     186 diff = (out_std - out_keops).abs()
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/attention/MHA.py:111, in KeOpsMultiHeadAttention.forward(self, x, mask)
#     107     mask_full = mask_full.unsqueeze(-1)
#     109 # Evaluate the KeOps operator
#     110 # We pass self.scale as a float tensor for the Pm(4) parameter
# --> 111 out = self.attn_op(q, k, mask_full, v, torch.tensor([self.scale], device=x.device))
#     113 # out shape = (B, n, head_dim)
#     114 out = out.reshape(b, self.num_heads, n, self.head_dim)
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pykeops/torch/generic/generic_red.py:687, in Genred.__call__(self, backend, device_id, ranges, out, *args)
#     685 params.ny = ny
#     686 params.out = out
# --> 687 out = GenredAutograd_fun(params, *args)
#     689 return postprocess(out, "torch", self.reduction_op, nout, self.opt_arg, dtype)
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pykeops/torch/generic/generic_red.py:383, in GenredAutograd_fun(*inputs)
#     382 def GenredAutograd_fun(*inputs):
# --> 383     return GenredAutograd.apply(*inputs)[0]
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/torch/autograd/function.py:553, in Function.apply(cls, *args, **kwargs)
#     550 if not torch._C._are_functorch_transforms_active():
#     551     # See NOTE: [functorch vjp and autograd interaction]
#     552     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 553     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     555 if not is_setup_ctx_defined:
#     556     raise RuntimeError(
#     557         "In order to use an autograd.Function with functorch transforms "
#     558         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     559         "staticmethod. For more details, please see "
#     560         "https://pytorch.org/docs/master/notes/extending.func.html"
#     561     )
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pykeops/torch/generic/generic_red.py:291, in GenredAutograd.forward(*inputs)
#     289 @staticmethod
#     290 def forward(*inputs):
# --> 291     return GenredAutograd_base._forward(*inputs)
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pykeops/torch/generic/generic_red.py:91, in GenredAutograd_base._forward(params, *args)
#      85 device_id, device_args = set_device(
#      86     tagCPUGPU, tagHostDevice, params.device_id_request, *args
#      87 )
#      89 from pykeops.common.keops_io import keops_binder
# ---> 91 myconv = keops_binder["nvrtc" if tagCPUGPU else "cpp"](
#      92     tagCPUGPU,
#      93     tag1D2D,
#      94     tagHostDevice,
#      95     use_ranges,
#      96     device_id,
#      97     params.formula,
#      98     params.aliases,
#      99     len(args),
#     100     params.dtype,
#     101     "torch",
#     102     params.optional_flags,
#     103 ).import_module()
#     105 # N.B.: KeOps C++ expects contiguous data arrays
#     106 test_contig = all(arg.is_contiguous() for arg in args)
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/keopscore/utils/Cache.py:91, in Cache_partial.__call__(self, *args)
#      89     self.library[str_id] = self.cls(params, fast_init=True)
#      90 else:
# ---> 91     obj = self.cls(*args)
#      92     self.library_params[str_id] = obj.params
#      93     self.library[str_id] = obj
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pykeops/common/keops_io/LoadKeOps_nvrtc.py:16, in LoadKeOps_nvrtc_class.__init__(self, fast_init, *args)
#      15 def __init__(self, *args, fast_init=False):
# ---> 16     super().__init__(*args, fast_init=fast_init)
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pykeops/common/keops_io/LoadKeOps.py:18, in LoadKeOps.__init__(self, fast_init, *args)
#      16     self.params = args[0]
#      17 else:
# ---> 18     self.init(*args)
#      19 self.dimout = self.params.dim
#      20 self.tagIJ = self.params.tagI
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/pykeops/common/keops_io/LoadKeOps.py:127, in LoadKeOps.init(self, tagCPUGPU, tag1D2D, tagHostDevice, use_ranges, device_id_request, formula, aliases, nargs, dtype, lang, optional_flags)
#     104 if use_ranges:
#     105     map_reduce_id += "_ranges"
#     107 (
#     108     self.params.tag,
#     109     self.params.source_name,
#     110     self.params.low_level_code_file,
#     111     self.params.tagI,
#     112     self.params.tagZero,
#     113     self.params.use_half,
#     114     self.params.use_fast_math,
#     115     self.params.cuda_block_size,
#     116     self.params.use_chunk_mode,
#     117     self.params.tag1D2D,
#     118     self.params.dimred,
#     119     self.params.dim,
#     120     self.params.dimy,
#     121     indsi,
#     122     indsj,
#     123     indsp,
#     124     dimsx,
#     125     dimsy,
#     126     dimsp,
# --> 127 ) = get_keops_dll(
#     128     map_reduce_id,
#     129     self.params.red_formula_string,
#     130     self.params.enable_chunks,
#     131     self.params.enable_final_chunks,
#     132     self.params.mult_var_highdim,
#     133     self.params.aliases,
#     134     nargs,
#     135     self.params.c_dtype,
#     136     self.params.c_dtype_acc,
#     137     self.params.sum_scheme,
#     138     self.params.tagHostDevice,
#     139     tagCPUGPU,
#     140     tag1D2D,
#     141     self.params.use_half,
#     142     self.params.use_fast_math,
#     143     device_id_request,
#     144 )
#     146 # now we switch indsi, indsj and dimsx, dimsy in case tagI=1.
#     147 # This is to be consistent with the convention used in the old
#     148 # bindings (see functions GetIndsI, GetIndsJ, GetDimsX, GetDimsY
#     149 # from file binder_interface.h. Clearly we could do better if we
#     150 # carefully rewrite some parts of the code
#     151 if self.params.tagI == 1:
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/keopscore/utils/Cache.py:32, in Cache.__call__(self, *args)
#      30 str_id = "".join(list(str(arg) for arg in args)) + str(env_param())
#      31 if not str_id in self.library:
# ---> 32     self.library[str_id] = self.fun(*args)
#      33 return self.library[str_id]
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/keopscore/get_keops_dll.py:97, in get_keops_dll_impl(map_reduce_id, red_formula_string, enable_chunks, enable_finalchunks, mul_var_highdim, aliases, *args)
#      95 set_enable_finalchunk(enable_finalchunks)
#      96 set_mult_var_highdim(mul_var_highdim)
# ---> 97 red_formula = GetReduction(red_formula_string, aliases)
#      98 if use_final_chunks(red_formula) and map_reduce_id != "GpuReduc2D":
#      99     use_chunk_mode = 2
#
# File ~/miniconda3/envs/jupyter/lib/python3.12/site-packages/keopscore/formulas/GetReduction.py:33, in GetReduction.__new__(self, red_formula_string, aliases)
#      31         varname, var = alias.split("=")
#      32         aliases_dict[varname] = eval(var)
# ---> 33 reduction = eval(red_formula_string, globals(), aliases_dict)
#      34 if keopscore.auto_factorize:
#      35     formula = reduction.children[0]
#
# File <string>:1
#
# NameError: name 'SoftMax' is not defined

# %%
from MLA import seq_lengths_latent, times_latent_standard, times_latent_keops

# %%
plt.figure(figsize=(8,5))
plt.plot(seq_lengths_latent, times_latent_standard, marker='o', label='Standard Latent Attention')
plt.plot(seq_lengths_latent, times_latent_keops, marker='s', label='KeOps Latent Attention')
plt.xlabel("Sequence Length")
plt.ylabel("Forward Pass Time (ms)")
plt.title("Runtime vs Sequence Length (Latent Attention)")
plt.legend()
plt.show()
